# %% [markdown]
# ### 1. Load packages

# %%
import numpy as np
import pandas as pd
import json
import requests
from tqdm import tqdm

# %% [markdown]
# ### 2. Functions

# %%
def get_first_page_per_country(country):
    api_search = f"https://www.xeno-canto.org/api/2/recordings?query=cnt:{country}"
    response = requests.get(api_search)
    if response.status_code == 200:
        #print(response.status_code)
        response_payload = json.loads(response.content)
        return response_payload
    else:
        return None

# %%
def get_page_per_country(country, page):
    api_search = f"https://www.xeno-canto.org/api/2/recordings?query=cnt:{country}&page={page}"
    response = requests.get(api_search)
    if response.status_code == 200:
        #print(response.status_code)
        response_payload = json.loads(response.content)
        return response_payload
    else:
        return None

# %%
def inspect_json(json_data):
    print(f"recordings: {json_data['numRecordings']}")
    print(f"species: {json_data['numSpecies']}")
    print(f"page: {json_data['page']}")
    print(f"number pages: {json_data['numPages']}")

# %%
def get_recordings(payload):
    return payload["recordings"]

# %%
def download_suite_from_country(country, country_initial_payload):
    pages = country_initial_payload["numPages"]
    
    all_recordings = []
    all_recordings = all_recordings + get_recordings(country_initial_payload)
    for page in tqdm(range(2,pages+1)):
        payload = get_page_per_country(country, page)
        recordings = get_recordings(payload)
        all_recordings = all_recordings + recordings
    
    return all_recordings

# %% [markdown]
# ### 3. Download birds from Romania

# %%
birds_romania = get_first_page_per_country("romania")
inspect_json(birds_romania)
print(f"recordings: {len(get_recordings(birds_romania))}")
suite_romania = download_suite_from_country("romania", birds_romania)
data_df = pd.DataFrame.from_records(suite_romania)
data_df.to_csv("birds_romania.csv", index=False)
# Out:
# recordings: 445
# species: 139
# page: 1
# number pages: 1
# recordings: 445
# 0it [00:00, ?it/s]

# %%
pd.set_option('max_columns', 30)
pd.set_option('max_colwidth', 100)
data_df.head()
# Out:
#        id    gen         sp ssp                           en             rec  \
# 0  509597  Anser  albifrons      Greater White-fronted Goose  Yoann Blanchon
# 1  509519  Anser  albifrons      Greater White-fronted Goose  Yoann Blanchon
# 2  509497  Anser  albifrons      Greater White-fronted Goose  Yoann Blanchon
# 3  509496  Anser  albifrons      Greater White-fronted Goose  Yoann Blanchon
# 4  509494  Anser  albifrons      Greater White-fronted Goose  Yoann Blanchon
#
#        cnt                                      loc      lat      lng alt  \
# 0  Romania    Municipiul Călărași, Județul Călărași  44.1625  27.3175  10
# 1  Romania   Comuna Valea Nucarilor, Județul Tulcea  45.0068  28.8792  20
# 2  Romania  Amara, Comuna Balta Albă, Județul Buzău  45.2365  27.2837  30
# 3  Romania  Amara, Comuna Balta Albă, Județul Buzău  45.2365  27.2837  30
# 4  Romania  Amara, Comuna Balta Albă, Județul Buzău  45.2365  27.2837  30
#
#           type                          url  \
# 0  flight call  //www.xeno-canto.org/509597
# 1  flight call  //www.xeno-canto.org/509519
# 2  flight call  //www.xeno-canto.org/509497
# 3  flight call  //www.xeno-canto.org/509496
# 4  flight call  //www.xeno-canto.org/509494
#
#                                    file  \
# 0  //www.xeno-canto.org/509597/download
# 1  //www.xeno-canto.org/509519/download
# 2  //www.xeno-canto.org/509497/download
# 3  //www.xeno-canto.org/509496/download
# 4  //www.xeno-canto.org/509494/download
#
#                                        file-name  \
# 0  XC509597-191130-083259_Anser albifrons_YB.mp3
# 1  XC509519-191127-144020_Anser albifrons_YB.mp3
# 2  XC509497-191125-144218_Anser albifrons_YB.mp3
# 3  XC509496-191125-143854_Anser albifrons_YB.mp3
# 4  XC509494-191125-143208_Anser albifrons_YB.mp3
#
#                                                                                                   sono  \
# 0  {'small': '//www.xeno-canto.org/sounds/uploaded/OYXLQBTHRH/ffts/XC509597-small.png', 'med': '//w...
# 1  {'small': '//www.xeno-canto.org/sounds/uploaded/OYXLQBTHRH/ffts/XC509519-small.png', 'med': '//w...
# 2  {'small': '//www.xeno-canto.org/sounds/uploaded/OYXLQBTHRH/ffts/XC509497-small.png', 'med': '//w...
# 3  {'small': '//www.xeno-canto.org/sounds/uploaded/OYXLQBTHRH/ffts/XC509496-small.png', 'med': '//w...
# 4  {'small': '//www.xeno-canto.org/sounds/uploaded/OYXLQBTHRH/ffts/XC509494-small.png', 'med': '//w...
#
#                                             lic  q length   time        date  \
# 0  //creativecommons.org/licenses/by-nc-sa/4.0/  A   0:30  09:30  2019-11-30
# 1  //creativecommons.org/licenses/by-nc-sa/4.0/  A   0:26  16:00  2019-11-27
# 2  //creativecommons.org/licenses/by-nc-sa/4.0/  B   0:12  15:30  2019-11-25
# 3  //creativecommons.org/licenses/by-nc-sa/4.0/  B   0:12  15:30  2019-11-25
# 4  //creativecommons.org/licenses/by-nc-sa/4.0/  B   0:17  15:30  2019-11-25
#
#      uploaded also                                                      rmk  \
# 0  2019-12-02   []  SennheiserME66-K6/ZOOM H2n ; High Pass Filter 500Hz 6db
# 1  2019-12-01   []                               SennheiserME66-K6/ZOOM H2n
# 2  2019-12-01   []  SennheiserME66-K6/ZOOM H2n ; High Pass Filter 500Hz 6db
# 3  2019-12-01   []  SennheiserME66-K6/ZOOM H2n ; High Pass Filter 500Hz 6db
# 4  2019-12-01   []  SennheiserME66-K6/ZOOM H2n ; High Pass Filter 500Hz 6db
#
#   bird-seen playback-used
# 0       yes            no
# 1       yes            no
# 2       yes            no
# 3       yes            no
# 4       yes            no

# %% [markdown]
# ### 4. Download birds from France

# %%
birds_france = get_first_page_per_country("france")
inspect_json(birds_france)
print(f"recordings: {len(get_recordings(birds_france))}")
suite_france = download_suite_from_country("france", birds_france)
data_df = pd.DataFrame.from_records(suite_france)
data_df.to_csv("birds_france.csv", index=False)
# Out:
# recordings: 20852
# species: 531
# page: 1
# number pages: 42
# recordings: 500
# 100%|██████████████████████████████████████████████████████████████████████████████████| 41/41 [00:39<00:00,  1.05it/s]

# %%
pd.set_option('max_columns', 30)
pd.set_option('max_colwidth', 100)
data_df.head()
# Out:
#        id          gen          sp ssp                            en  \
# 0  369589  Dendrocygna  autumnalis      Black-bellied Whistling Duck
# 1  367073  Dendrocygna  autumnalis      Black-bellied Whistling Duck
# 2  367072  Dendrocygna  autumnalis      Black-bellied Whistling Duck
# 3  542364       Branta    bernicla                       Brant Goose
# 4  541405       Branta    bernicla                       Brant Goose
#
#                rec     cnt  \
# 0  Stanislas Wroza  France
# 1  Stanislas Wroza  France
# 2  Stanislas Wroza  France
# 3    Gaëtan Mineau  France
# 4    Julien Piette  France
#
#                                                                   loc  \
# 0                                 Vauvert, Gard, Languedoc-Roussillon
# 1  Saint-Martin-de-Crau, Bouches-du-Rhône, Provence-Alpes-Côte d'Azur
# 2  Saint-Martin-de-Crau, Bouches-du-Rhône, Provence-Alpes-Côte d'Azur
# 3                                           Augan, Morbihan, Bretagne
# 4                                    Dunkerque, Nord, Hauts-de-France
#
#        lat      lng alt                   type                          url  \
# 0  43.6073   4.2865   0            flight call  //www.xeno-canto.org/369589
# 1  43.6368   4.8048  20                   song  //www.xeno-canto.org/367073
# 2  43.6368   4.8048  20                   song  //www.xeno-canto.org/367072
# 3  47.9189  -2.2797  90  nocturnal flight call  //www.xeno-canto.org/542364
# 4  51.0445   2.3912  10  nocturnal flight call  //www.xeno-canto.org/541405
#
#                                    file  \
# 0  //www.xeno-canto.org/369589/download
# 1  //www.xeno-canto.org/367073/download
# 2  //www.xeno-canto.org/367072/download
# 3  //www.xeno-canto.org/542364/download
# 4  //www.xeno-canto.org/541405/download
#
#                                         file-name  \
# 0          XC369589-Dendrocygne a ventre noir.mp3
# 1  XC367073-Dendrocygne a ventre noir chant 2.mp3
# 2  XC367072-Dendrocygne a ventre noir chant 1.mp3
# 3   XC542364-Bernache_cravant_nf_050420_22h00.mp3
# 4            XC541405-200402_bernache cravant.mp3
#
#                                                                                                   sono  \
# 0  {'small': '//www.xeno-canto.org/sounds/uploaded/SDPCHKOHRH/ffts/XC369589-small.png', 'med': '//w...
# 1  {'small': '//www.xeno-canto.org/sounds/uploaded/SDPCHKOHRH/ffts/XC367073-small.png', 'med': '//w...
# 2  {'small': '//www.xeno-canto.org/sounds/uploaded/SDPCHKOHRH/ffts/XC367072-small.png', 'med': '//w...
# 3  {'small': '//www.xeno-canto.org/sounds/uploaded/NPDCTXNQKI/ffts/XC542364-small.png', 'med': '//w...
# 4  {'small': '//www.xeno-canto.org/sounds/uploaded/AEYBSAOVGN/ffts/XC541405-small.png', 'med': '//w...
#
#                                             lic         q length   time  \
# 0  //creativecommons.org/licenses/by-nc-sa/4.0/         A   1:09  06:30
# 1  //creativecommons.org/licenses/by-nc-sa/4.0/         D   0:11  14:00
# 2  //creativecommons.org/licenses/by-nc-sa/4.0/         D   0:26  14:00
# 3  //creativecommons.org/licenses/by-nc-sa/4.0/  no score   0:07  22:00
# 4  //creativecommons.org/licenses/by-nc-sa/4.0/  no score   0:21  02:32
#
#          date    uploaded also               rmk bird-seen playback-used
# 0  2017-05-12  2017-05-12   []                         yes            no
# 1  2017-04-29  2017-04-30   []  Feral population       yes            no
# 2  2017-04-29  2017-04-30   []  Feral population       yes            no
# 3  2020-04-05  2020-04-06   []                          no            no
# 4  2020-04-03  2020-04-04   []                     unknown       unknown

# %%
data_df.shape
# Out:
# (20852, 26)
